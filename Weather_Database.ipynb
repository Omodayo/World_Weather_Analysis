# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy module.
from citipy import citipy

# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 807

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create query for each city.
city_url = url + "&q=" + city.replace(" ","+")

# API call with open weather map.
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': 12.6934, 'lat': 67.667},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 44.6,
#   'feels_like': 37.44,
#   'temp_min': 44.6,
#   'temp_max': 44.6,
#   'pressure': 1025,
#   'humidity': 76},
#  'visibility': 10000,
#  'wind': {'speed': 16.11, 'deg': 180},
#  'clouds': {'all': 0},
#  'dt': 1618774977,
#  'sys': {'type': 1,
#   'id': 1661,
#   'country': 'NO',
#   'sunrise': 1618715189,
#   'sunset': 1618773011},
#  'timezone': 7200,
#  'id': 3137469,
#  'name': 'Sørland',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print start of cities search.
print("Starting Cities Search     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 100 for logging purposes.
    if (i % 100 == 0 and i >= 100):
        set_count += 1
        record_count = 1
    # Create query for each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the query, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Cities Search Completed      ")
print("-----------------------------")
# Out:
# Starting Cities Search
# -----------------------------
# Processing Record 1 of Set 1 | tuatapere
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | the valley
# Processing Record 4 of Set 1 | adiake
# Processing Record 5 of Set 1 | antofagasta
# Processing Record 6 of Set 1 | lander
# Processing Record 7 of Set 1 | vanimo
# Processing Record 8 of Set 1 | vao
# Processing Record 9 of Set 1 | sola
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | vestmannaeyjar
# Processing Record 12 of Set 1 | pisco
# Processing Record 13 of Set 1 | bethel
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | bambous virieux
# Processing Record 16 of Set 1 | copperas cove
# Processing Record 17 of Set 1 | bathsheba
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | bilibino
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | brownsville
# Processing Record 22 of Set 1 | khandagayty
# Processing Record 23 of Set 1 | ancud
# Processing Record 24 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 1 | narsaq
# Processing Record 26 of Set 1 | castro
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | kavieng
# Processing Record 29 of Set 1 | esperance
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | lusambo
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | kodiak
# Processing Record 34 of Set 1 | isangel
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | nikolskoye
# Processing Record 37 of Set 1 | roma
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | sivaki
# Processing Record 40 of Set 1 | huarmey
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | vila velha
# Processing Record 44 of Set 1 | lahaina
# Processing Record 45 of Set 1 | gobabis
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | hofn
# Processing Record 48 of Set 1 | talnakh
# Processing Record 49 of Set 1 | bakel
# Processing Record 50 of Set 1 | hilo
# Processing Record 51 of Set 1 | ginda
# Processing Record 52 of Set 1 | les cayes
# Processing Record 53 of Set 1 | cape town
# Processing Record 54 of Set 1 | airai
# Processing Record 55 of Set 1 | tactic
# Processing Record 56 of Set 1 | barga
# Processing Record 57 of Set 1 | bairiki
# Processing Record 58 of Set 1 | alyangula
# Processing Record 59 of Set 1 | gbarnga
# Processing Record 60 of Set 1 | chhindwara
# Processing Record 61 of Set 1 | ierissos
# Processing Record 62 of Set 1 | mackay
# Processing Record 63 of Set 1 | chuy
# Processing Record 64 of Set 1 | albany
# Processing Record 65 of Set 1 | new norfolk
# Processing Record 66 of Set 1 | darhan
# Processing Record 67 of Set 1 | sikasso
# Processing Record 68 of Set 1 | carnarvon
# Processing Record 69 of Set 1 | ponta do sol
# Processing Record 70 of Set 1 | batagay
# Processing Record 71 of Set 1 | kargasok
# Processing Record 72 of Set 1 | guane
# Processing Record 73 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 74 of Set 1 | korem
# Processing Record 75 of Set 1 | teya
# Processing Record 76 of Set 1 | synya
# Processing Record 77 of Set 1 | yellowknife
# Processing Record 78 of Set 1 | east london
# Processing Record 79 of Set 1 | mocuba
# Processing Record 80 of Set 1 | tairua
# Processing Record 81 of Set 1 | provideniya
# Processing Record 82 of Set 1 | tura
# Processing Record 83 of Set 1 | sao filipe
# Processing Record 84 of Set 1 | port-gentil
# Processing Record 85 of Set 1 | el limon
# Processing Record 86 of Set 1 | nouadhibou
# Processing Record 87 of Set 1 | marion
# Processing Record 88 of Set 1 | shelburne
# Processing Record 89 of Set 1 | puerto ayora
# Processing Record 90 of Set 1 | butaritari
# Processing Record 91 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 92 of Set 1 | lebu
# Processing Record 93 of Set 1 | cheuskiny
# City not found. Skipping...
# Processing Record 94 of Set 1 | hobyo
# Processing Record 95 of Set 1 | kavaratti
# Processing Record 96 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 97 of Set 1 | tiarei
# Processing Record 98 of Set 1 | san felipe
# Processing Record 99 of Set 1 | chapais
# Processing Record 100 of Set 1 | gat
# Processing Record 1 of Set 2 | saint-francois
# Processing Record 2 of Set 2 | san pablo
# Processing Record 3 of Set 2 | zaraza
# Processing Record 4 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 2 | vostok
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | victoria
# Processing Record 8 of Set 2 | virginia beach
# Processing Record 9 of Set 2 | clyde river
# Processing Record 10 of Set 2 | kieta
# Processing Record 11 of Set 2 | maple creek
# Processing Record 12 of Set 2 | lompoc
# Processing Record 13 of Set 2 | shchuchye
# City not found. Skipping...
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | pizarro
# Processing Record 16 of Set 2 | lensk
# Processing Record 17 of Set 2 | ostersund
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | manokwari
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | saint george
# Processing Record 22 of Set 2 | santa rosa
# Processing Record 23 of Set 2 | palu
# Processing Record 24 of Set 2 | birao
# Processing Record 25 of Set 2 | muros
# Processing Record 26 of Set 2 | mount isa
# Processing Record 27 of Set 2 | maba
# Processing Record 28 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 2 | loukhi
# Processing Record 30 of Set 2 | revelstoke
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | diffa
# Processing Record 33 of Set 2 | antigonish
# Processing Record 34 of Set 2 | mulege
# Processing Record 35 of Set 2 | deputatskiy
# Processing Record 36 of Set 2 | yulara
# Processing Record 37 of Set 2 | ahipara
# Processing Record 38 of Set 2 | balezino
# Processing Record 39 of Set 2 | thaton
# Processing Record 40 of Set 2 | itaituba
# Processing Record 41 of Set 2 | kruisfontein
# Processing Record 42 of Set 2 | port alfred
# Processing Record 43 of Set 2 | hasaki
# Processing Record 44 of Set 2 | nkhotakota
# Processing Record 45 of Set 2 | urusha
# Processing Record 46 of Set 2 | codrington
# Processing Record 47 of Set 2 | savonlinna
# Processing Record 48 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 49 of Set 2 | bastia
# Processing Record 50 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 51 of Set 2 | pevek
# Processing Record 52 of Set 2 | batatais
# Processing Record 53 of Set 2 | kirakira
# Processing Record 54 of Set 2 | arraial do cabo
# Processing Record 55 of Set 2 | baruun-urt
# Processing Record 56 of Set 2 | port elizabeth
# Processing Record 57 of Set 2 | tautira
# Processing Record 58 of Set 2 | liwale
# Processing Record 59 of Set 2 | cap malheureux
# Processing Record 60 of Set 2 | acapulco
# Processing Record 61 of Set 2 | arman
# Processing Record 62 of Set 2 | atuona
# Processing Record 63 of Set 2 | abnub
# Processing Record 64 of Set 2 | okhotsk
# Processing Record 65 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 66 of Set 2 | upernavik
# Processing Record 67 of Set 2 | jamestown
# Processing Record 68 of Set 2 | kachiry
# Processing Record 69 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 70 of Set 2 | paka
# Processing Record 71 of Set 2 | sussex
# Processing Record 72 of Set 2 | klaksvik
# Processing Record 73 of Set 2 | komsomolskiy
# Processing Record 74 of Set 2 | berlevag
# Processing Record 75 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 76 of Set 2 | poya
# Processing Record 77 of Set 2 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 78 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 79 of Set 2 | paraiso
# Processing Record 80 of Set 2 | erenhot
# Processing Record 81 of Set 2 | klyuchi
# Processing Record 82 of Set 2 | northam
# Processing Record 83 of Set 2 | bredasdorp
# Processing Record 84 of Set 2 | bartica
# Processing Record 85 of Set 2 | husavik
# Processing Record 86 of Set 2 | gulshat
# City not found. Skipping...
# Processing Record 87 of Set 2 | ostrovnoy
# Processing Record 88 of Set 2 | ridgecrest
# Processing Record 89 of Set 2 | fortuna
# Processing Record 90 of Set 2 | sayyan
# Processing Record 91 of Set 2 | touros
# Processing Record 92 of Set 2 | illertissen
# Processing Record 93 of Set 2 | waingapu
# Processing Record 94 of Set 2 | mar del plata
# Processing Record 95 of Set 2 | kardymovo
# Processing Record 96 of Set 2 | khatanga
# Processing Record 97 of Set 2 | ilulissat
# Processing Record 98 of Set 2 | altar
# Processing Record 99 of Set 2 | pavlovka
# Processing Record 100 of Set 2 | tuktoyaktuk
# Processing Record 1 of Set 3 | coquimbo
# Processing Record 2 of Set 3 | namibe
# Processing Record 3 of Set 3 | cockburn town
# Processing Record 4 of Set 3 | hanyang
# Processing Record 5 of Set 3 | poso
# Processing Record 6 of Set 3 | yeppoon
# Processing Record 7 of Set 3 | buraydah
# Processing Record 8 of Set 3 | mikuni
# Processing Record 9 of Set 3 | kidal
# Processing Record 10 of Set 3 | brae
# Processing Record 11 of Set 3 | sorkjosen
# Processing Record 12 of Set 3 | tasiilaq
# Processing Record 13 of Set 3 | leh
# Processing Record 14 of Set 3 | baton rouge
# Processing Record 15 of Set 3 | luderitz
# Processing Record 16 of Set 3 | comodoro rivadavia
# Processing Record 17 of Set 3 | poum
# Processing Record 18 of Set 3 | kutum
# Processing Record 19 of Set 3 | onega
# Processing Record 20 of Set 3 | la ronge
# Processing Record 21 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 3 | almaznyy
# Processing Record 23 of Set 3 | ganzhou
# Processing Record 24 of Set 3 | huilong
# Processing Record 25 of Set 3 | kailua
# Processing Record 26 of Set 3 | turukhansk
# Processing Record 27 of Set 3 | nelson bay
# Processing Record 28 of Set 3 | kalengwa
# Processing Record 29 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 30 of Set 3 | puerto ayacucho
# Processing Record 31 of Set 3 | matara
# Processing Record 32 of Set 3 | dhone
# Processing Record 33 of Set 3 | pangai
# Processing Record 34 of Set 3 | longyearbyen
# Processing Record 35 of Set 3 | henties bay
# Processing Record 36 of Set 3 | mahebourg
# Processing Record 37 of Set 3 | niamey
# Processing Record 38 of Set 3 | torbay
# Processing Record 39 of Set 3 | dudinka
# Processing Record 40 of Set 3 | alta floresta
# Processing Record 41 of Set 3 | nara
# Processing Record 42 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 3 | belmonte
# Processing Record 44 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 3 | sitka
# Processing Record 46 of Set 3 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 47 of Set 3 | singkang
# Processing Record 48 of Set 3 | ballina
# Processing Record 49 of Set 3 | svetlaya
# Processing Record 50 of Set 3 | menomonie
# Processing Record 51 of Set 3 | natal
# Processing Record 52 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 53 of Set 3 | abu dhabi
# Processing Record 54 of Set 3 | hobart
# Processing Record 55 of Set 3 | morant bay
# Processing Record 56 of Set 3 | port hedland
# Processing Record 57 of Set 3 | faya
# Processing Record 58 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 59 of Set 3 | mount gambier
# Processing Record 60 of Set 3 | khomutovo
# Processing Record 61 of Set 3 | pinega
# Processing Record 62 of Set 3 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 63 of Set 3 | mancio lima
# Processing Record 64 of Set 3 | chokwe
# Processing Record 65 of Set 3 | moron
# Processing Record 66 of Set 3 | barrow
# Processing Record 67 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 68 of Set 3 | kununurra
# Processing Record 69 of Set 3 | cabo san lucas
# Processing Record 70 of Set 3 | ambon
# Processing Record 71 of Set 3 | constitucion
# Processing Record 72 of Set 3 | olafsvik
# Processing Record 73 of Set 3 | vilyuysk
# Processing Record 74 of Set 3 | paamiut
# Processing Record 75 of Set 3 | tornio
# Processing Record 76 of Set 3 | salalah
# Processing Record 77 of Set 3 | sharan
# Processing Record 78 of Set 3 | makat
# Processing Record 79 of Set 3 | norman wells
# Processing Record 80 of Set 3 | porto novo
# Processing Record 81 of Set 3 | prachuap khiri khan
# Processing Record 82 of Set 3 | camopi
# Processing Record 83 of Set 3 | kropotkin
# Processing Record 84 of Set 3 | whitehorse
# Processing Record 85 of Set 3 | siloam springs
# Processing Record 86 of Set 3 | aberdeen
# Processing Record 87 of Set 3 | ajaccio
# Processing Record 88 of Set 3 | cherskiy
# Processing Record 89 of Set 3 | puerto leguizamo
# Processing Record 90 of Set 3 | sibolga
# Processing Record 91 of Set 3 | tibirita
# Processing Record 92 of Set 3 | joao pinheiro
# Processing Record 93 of Set 3 | rocha
# Processing Record 94 of Set 3 | lamu
# Processing Record 95 of Set 3 | salta
# Processing Record 96 of Set 3 | kudahuvadhoo
# Processing Record 97 of Set 3 | changtu
# Processing Record 98 of Set 3 | sao joao da barra
# Processing Record 99 of Set 3 | bowen
# Processing Record 100 of Set 3 | rawson
# Processing Record 1 of Set 4 | san quintin
# Processing Record 2 of Set 4 | iqaluit
# Processing Record 3 of Set 4 | ekibastuz
# Processing Record 4 of Set 4 | general pico
# Processing Record 5 of Set 4 | sao fidelis
# Processing Record 6 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 4 | fuzhou
# Processing Record 8 of Set 4 | teeli
# Processing Record 9 of Set 4 | nouakchott
# Processing Record 10 of Set 4 | herat
# Processing Record 11 of Set 4 | carutapera
# Processing Record 12 of Set 4 | leningradskiy
# Processing Record 13 of Set 4 | hermanus
# Processing Record 14 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 4 | calama
# Processing Record 16 of Set 4 | margate
# Processing Record 17 of Set 4 | porbandar
# Processing Record 18 of Set 4 | saint anthony
# Processing Record 19 of Set 4 | meulaboh
# Processing Record 20 of Set 4 | san roque
# Processing Record 21 of Set 4 | kolimvari
# City not found. Skipping...
# Processing Record 22 of Set 4 | berdigestyakh
# Processing Record 23 of Set 4 | naantali
# Processing Record 24 of Set 4 | bima
# Processing Record 25 of Set 4 | dabat
# Processing Record 26 of Set 4 | victor harbor
# Processing Record 27 of Set 4 | broome
# Processing Record 28 of Set 4 | kaltan
# Processing Record 29 of Set 4 | sao jose da coroa grande
# Processing Record 30 of Set 4 | davila
# Processing Record 31 of Set 4 | kurmanayevka
# Processing Record 32 of Set 4 | pahrump
# Processing Record 33 of Set 4 | xining
# Processing Record 34 of Set 4 | khandyga
# Processing Record 35 of Set 4 | coihaique
# Processing Record 36 of Set 4 | baykit
# Processing Record 37 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 4 | nizhniy tsasuchey
# Processing Record 39 of Set 4 | lodja
# Processing Record 40 of Set 4 | santa marinella
# Processing Record 41 of Set 4 | achisay
# City not found. Skipping...
# Processing Record 42 of Set 4 | fairbanks
# Processing Record 43 of Set 4 | sambava
# Processing Record 44 of Set 4 | faanui
# Processing Record 45 of Set 4 | marawi
# Processing Record 46 of Set 4 | banda aceh
# Processing Record 47 of Set 4 | asosa
# Processing Record 48 of Set 4 | laguna
# Processing Record 49 of Set 4 | vila
# Processing Record 50 of Set 4 | nanortalik
# Processing Record 51 of Set 4 | dali
# Processing Record 52 of Set 4 | saurimo
# Processing Record 53 of Set 4 | grindavik
# Processing Record 54 of Set 4 | marienburg
# Processing Record 55 of Set 4 | koungou
# Processing Record 56 of Set 4 | huambo
# Processing Record 57 of Set 4 | kemptville
# Processing Record 58 of Set 4 | dingle
# Processing Record 59 of Set 4 | cahul
# Processing Record 60 of Set 4 | eskil
# Processing Record 61 of Set 4 | afua
# Processing Record 62 of Set 4 | karratha
# Processing Record 63 of Set 4 | general roca
# Processing Record 64 of Set 4 | harper
# Processing Record 65 of Set 4 | nanyamba
# Processing Record 66 of Set 4 | fukue
# Processing Record 67 of Set 4 | murska sobota
# Processing Record 68 of Set 4 | georgetown
# Processing Record 69 of Set 4 | alamosa
# Processing Record 70 of Set 4 | mareeba
# Processing Record 71 of Set 4 | caravelas
# Processing Record 72 of Set 4 | balabac
# Processing Record 73 of Set 4 | lorengau
# Processing Record 74 of Set 4 | genhe
# Processing Record 75 of Set 4 | samana
# Processing Record 76 of Set 4 | sistranda
# Processing Record 77 of Set 4 | nizhniy kuranakh
# Processing Record 78 of Set 4 | biltine
# Processing Record 79 of Set 4 | oyama
# Processing Record 80 of Set 4 | damietta
# Processing Record 81 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 82 of Set 4 | brazzaville
# Processing Record 83 of Set 4 | linares
# Processing Record 84 of Set 4 | havelock
# Processing Record 85 of Set 4 | boa vista
# Processing Record 86 of Set 4 | calabar
# Processing Record 87 of Set 4 | cidreira
# Processing Record 88 of Set 4 | alice springs
# Processing Record 89 of Set 4 | bandarbeyla
# Processing Record 90 of Set 4 | galeana
# Processing Record 91 of Set 4 | kaitangata
# Processing Record 92 of Set 4 | mitzic
# Processing Record 93 of Set 4 | aklavik
# Processing Record 94 of Set 4 | wasilla
# Processing Record 95 of Set 4 | buchanan
# Processing Record 96 of Set 4 | albemarle
# Processing Record 97 of Set 4 | kralendijk
# Processing Record 98 of Set 4 | bengkulu
# Processing Record 99 of Set 4 | nome
# Processing Record 100 of Set 4 | felidhoo
# City not found. Skipping...
# Processing Record 1 of Set 5 | san policarpo
# Processing Record 2 of Set 5 | mayumba
# Processing Record 3 of Set 5 | belaya glina
# Processing Record 4 of Set 5 | kawalu
# Processing Record 5 of Set 5 | marsh harbour
# Processing Record 6 of Set 5 | ketou
# Processing Record 7 of Set 5 | gaoua
# Processing Record 8 of Set 5 | severo-kurilsk
# Processing Record 9 of Set 5 | honiara
# Processing Record 10 of Set 5 | cayenne
# Processing Record 11 of Set 5 | souillac
# Processing Record 12 of Set 5 | kalavai
# Processing Record 13 of Set 5 | vagur
# Processing Record 14 of Set 5 | killarney
# Processing Record 15 of Set 5 | naze
# Processing Record 16 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 17 of Set 5 | brandon
# Processing Record 18 of Set 5 | mersing
# Processing Record 19 of Set 5 | evensk
# Processing Record 20 of Set 5 | pundaguitan
# Processing Record 21 of Set 5 | iracoubo
# Processing Record 22 of Set 5 | jacareacanga
# Processing Record 23 of Set 5 | lamar
# Processing Record 24 of Set 5 | makakilo city
# Processing Record 25 of Set 5 | puerto escondido
# Processing Record 26 of Set 5 | port hardy
# Processing Record 27 of Set 5 | ossora
# Processing Record 28 of Set 5 | vanavara
# Processing Record 29 of Set 5 | ikom
# Processing Record 30 of Set 5 | bullhead city
# Processing Record 31 of Set 5 | elesbao veloso
# Processing Record 32 of Set 5 | sonoita
# Processing Record 33 of Set 5 | flinders
# Processing Record 34 of Set 5 | portland
# Processing Record 35 of Set 5 | umba
# Processing Record 36 of Set 5 | aginskoye
# Processing Record 37 of Set 5 | bogorodskoye
# Processing Record 38 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 5 | orapa
# Processing Record 40 of Set 5 | arlit
# Processing Record 41 of Set 5 | simoes
# Processing Record 42 of Set 5 | sao paulo de olivenca
# Processing Record 43 of Set 5 | rokiskis
# Processing Record 44 of Set 5 | kisangani
# Processing Record 45 of Set 5 | wamba
# Processing Record 46 of Set 5 | padang
# Processing Record 47 of Set 5 | emerald
# Processing Record 48 of Set 5 | jaguey grande
# Processing Record 49 of Set 5 | cape coast
# Processing Record 50 of Set 5 | zhigansk
# Processing Record 51 of Set 5 | koumac
# Processing Record 52 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 53 of Set 5 | mananjary
# Processing Record 54 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 55 of Set 5 | riyadh
# Processing Record 56 of Set 5 | karoi
# Processing Record 57 of Set 5 | beringovskiy
# Processing Record 58 of Set 5 | nurota
# Processing Record 59 of Set 5 | maragogi
# Processing Record 60 of Set 5 | erdenet
# Processing Record 61 of Set 5 | havoysund
# Processing Record 62 of Set 5 | usogorsk
# Processing Record 63 of Set 5 | porto murtinho
# Processing Record 64 of Set 5 | mbandaka
# Processing Record 65 of Set 5 | bilma
# Processing Record 66 of Set 5 | juba
# Processing Record 67 of Set 5 | maloy
# Processing Record 68 of Set 5 | ambilobe
# Processing Record 69 of Set 5 | jujuy
# City not found. Skipping...
# Processing Record 70 of Set 5 | katsuura
# Processing Record 71 of Set 5 | sarata
# Processing Record 72 of Set 5 | havre-saint-pierre
# Processing Record 73 of Set 5 | ukiah
# Processing Record 74 of Set 5 | orthez
# Processing Record 75 of Set 5 | portree
# Processing Record 76 of Set 5 | honningsvag
# Processing Record 77 of Set 5 | sabha
# Processing Record 78 of Set 5 | grand gaube
# Processing Record 79 of Set 5 | andrews
# Processing Record 80 of Set 5 | vigrestad
# Processing Record 81 of Set 5 | bonavista
# Processing Record 82 of Set 5 | jalu
# Processing Record 83 of Set 5 | kenai
# Processing Record 84 of Set 5 | quatre cocos
# Processing Record 85 of Set 5 | thomaston
# Processing Record 86 of Set 5 | alofi
# Processing Record 87 of Set 5 | taquarituba
# Processing Record 88 of Set 5 | hervey bay
# Processing Record 89 of Set 5 | siderno
# Processing Record 90 of Set 5 | kathmandu
# Processing Record 91 of Set 5 | chokurdakh
# Processing Record 92 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 93 of Set 5 | santiago del estero
# Processing Record 94 of Set 5 | katsiveli
# City not found. Skipping...
# Processing Record 95 of Set 5 | santa rita
# Processing Record 96 of Set 5 | bereda
# Processing Record 97 of Set 5 | hornepayne
# Processing Record 98 of Set 5 | trairi
# Processing Record 99 of Set 5 | grand baie
# Processing Record 100 of Set 5 | dandong
# Processing Record 1 of Set 6 | troitskoye
# Processing Record 2 of Set 6 | tiznit
# Processing Record 3 of Set 6 | nabire
# Processing Record 4 of Set 6 | antalaha
# Processing Record 5 of Set 6 | vardo
# Processing Record 6 of Set 6 | saldanha
# Processing Record 7 of Set 6 | half moon bay
# Processing Record 8 of Set 6 | lalmohan
# Processing Record 9 of Set 6 | winchester
# Processing Record 10 of Set 6 | zabol
# Processing Record 11 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 12 of Set 6 | puerto colombia
# Processing Record 13 of Set 6 | staryy nadym
# Processing Record 14 of Set 6 | barao de melgaco
# Processing Record 15 of Set 6 | san patricio
# Processing Record 16 of Set 6 | snezhnogorsk
# Processing Record 17 of Set 6 | mindelo
# Processing Record 18 of Set 6 | gazojak
# Processing Record 19 of Set 6 | pochutla
# Processing Record 20 of Set 6 | mapiripan
# Processing Record 21 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 22 of Set 6 | acarau
# Processing Record 23 of Set 6 | lagoa
# Processing Record 24 of Set 6 | venado tuerto
# Processing Record 25 of Set 6 | lasem
# Processing Record 26 of Set 6 | catio
# Processing Record 27 of Set 6 | ivankiv
# Processing Record 28 of Set 6 | ca mau
# Processing Record 29 of Set 6 | tynda
# Processing Record 30 of Set 6 | itanhaem
# Processing Record 31 of Set 6 | butterworth
# Processing Record 32 of Set 6 | mpulungu
# Processing Record 33 of Set 6 | zhezkazgan
# Processing Record 34 of Set 6 | tommot
# Processing Record 35 of Set 6 | port macquarie
# Processing Record 36 of Set 6 | port arthur
# Processing Record 37 of Set 6 | yilan
# Processing Record 38 of Set 6 | chumikan
# Processing Record 39 of Set 6 | marevo
# Processing Record 40 of Set 6 | umm lajj
# Processing Record 41 of Set 6 | kotido
# Processing Record 42 of Set 6 | morada nova
# Processing Record 43 of Set 6 | taltal
# Processing Record 44 of Set 6 | vila franca do campo
# Processing Record 45 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 46 of Set 6 | collie
# Processing Record 47 of Set 6 | athabasca
# Processing Record 48 of Set 6 | college
# Processing Record 49 of Set 6 | mithimna
# City not found. Skipping...
# Processing Record 50 of Set 6 | goderich
# Processing Record 51 of Set 6 | aykhal
# Processing Record 52 of Set 6 | lac du bonnet
# Processing Record 53 of Set 6 | aksarka
# Processing Record 54 of Set 6 | batticaloa
# Processing Record 55 of Set 6 | bolshoye soldatskoye
# City not found. Skipping...
# Processing Record 56 of Set 6 | tessalit
# Processing Record 57 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 58 of Set 6 | olga
# Processing Record 59 of Set 6 | ushtobe
# Processing Record 60 of Set 6 | nogliki
# Processing Record 61 of Set 6 | katav-ivanovsk
# Processing Record 62 of Set 6 | denia
# Processing Record 63 of Set 6 | halifax
# Processing Record 64 of Set 6 | barentu
# Processing Record 65 of Set 6 | qui nhon
# Processing Record 66 of Set 6 | bonney lake
# Processing Record 67 of Set 6 | namerikawa
# Processing Record 68 of Set 6 | pimentel
# Processing Record 69 of Set 6 | lujiang
# Processing Record 70 of Set 6 | leszno
# Processing Record 71 of Set 6 | adrar
# Processing Record 72 of Set 6 | inuvik
# Processing Record 73 of Set 6 | kostomuksha
# Processing Record 74 of Set 6 | caloundra
# Processing Record 75 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 76 of Set 6 | kloulklubed
# Processing Record 77 of Set 6 | tahta
# Processing Record 78 of Set 6 | fort-shevchenko
# Processing Record 79 of Set 6 | muroto
# Processing Record 80 of Set 6 | ratnagiri
# Processing Record 81 of Set 6 | real
# Processing Record 82 of Set 6 | algiers
# Processing Record 83 of Set 6 | ende
# Processing Record 84 of Set 6 | muyezerskiy
# Processing Record 85 of Set 6 | nioki
# Processing Record 86 of Set 6 | presidente dutra
# Processing Record 87 of Set 6 | miram shah
# Processing Record 88 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 89 of Set 6 | muisne
# Processing Record 90 of Set 6 | krasnoturansk
# Processing Record 91 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 92 of Set 6 | balikpapan
# Processing Record 93 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 94 of Set 6 | sillamae
# Processing Record 95 of Set 6 | busca
# Processing Record 96 of Set 6 | udachnyy
# Processing Record 97 of Set 6 | hojai
# Processing Record 98 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 99 of Set 6 | yar-sale
# Processing Record 100 of Set 6 | svetlogorsk
# Processing Record 1 of Set 7 | rio verde de mato grosso
# Processing Record 2 of Set 7 | cabatuan
# Processing Record 3 of Set 7 | guerrero negro
# Processing Record 4 of Set 7 | yamada
# Processing Record 5 of Set 7 | hamilton
# Processing Record 6 of Set 7 | shache
# Processing Record 7 of Set 7 | scarborough
# Processing Record 8 of Set 7 | morondava
# Processing Record 9 of Set 7 | det udom
# Processing Record 10 of Set 7 | rovaniemi
# Processing Record 11 of Set 7 | turbat
# Processing Record 12 of Set 7 | kaduy
# Processing Record 13 of Set 7 | lata
# Processing Record 14 of Set 7 | geraldton
# Processing Record 15 of Set 7 | kayerkan
# Processing Record 16 of Set 7 | valleyview
# Processing Record 17 of Set 7 | nipawin
# Processing Record 18 of Set 7 | champasak
# Processing Record 19 of Set 7 | vuktyl
# Processing Record 20 of Set 7 | homer
# Processing Record 21 of Set 7 | saint-pierre
# Processing Record 22 of Set 7 | aswan
# Processing Record 23 of Set 7 | tiksi
# Processing Record 24 of Set 7 | teplyk
# Processing Record 25 of Set 7 | sisimiut
# Processing Record 26 of Set 7 | pushkino
# Processing Record 27 of Set 7 | afanasyevo
# City not found. Skipping...
# Processing Record 28 of Set 7 | yertsevo
# Processing Record 29 of Set 7 | maningrida
# Processing Record 30 of Set 7 | salinopolis
# Processing Record 31 of Set 7 | lazaro cardenas
# Processing Record 32 of Set 7 | waddan
# Processing Record 33 of Set 7 | nuevo progreso
# Processing Record 34 of Set 7 | araguatins
# City not found. Skipping...
# Processing Record 35 of Set 7 | mnogovershinnyy
# Processing Record 36 of Set 7 | nemuro
# Processing Record 37 of Set 7 | teknaf
# Processing Record 38 of Set 7 | cam ranh
# Processing Record 39 of Set 7 | prince rupert
# Processing Record 40 of Set 7 | catuday
# Processing Record 41 of Set 7 | mitsamiouli
# Processing Record 42 of Set 7 | jutai
# Processing Record 43 of Set 7 | seddon
# Processing Record 44 of Set 7 | sorada
# Processing Record 45 of Set 7 | churapcha
# Processing Record 46 of Set 7 | rodental
# Processing Record 47 of Set 7 | aviles
# Processing Record 48 of Set 7 | kapoeta
# Processing Record 49 of Set 7 | jackson
# Processing Record 50 of Set 7 | eidfjord
# Processing Record 51 of Set 7 | mahon
# Processing Record 52 of Set 7 | ekhabi
# Processing Record 53 of Set 7 | pacific grove
# Processing Record 54 of Set 7 | back mountain
# Processing Record 55 of Set 7 | santa helena de goias
# Processing Record 56 of Set 7 | sakakah
# Processing Record 57 of Set 7 | nalut
# Processing Record 58 of Set 7 | ucluelet
# Processing Record 59 of Set 7 | pangnirtung
# Processing Record 60 of Set 7 | tome-acu
# City not found. Skipping...
# Processing Record 61 of Set 7 | aguada de pasajeros
# Processing Record 62 of Set 7 | mayo
# Processing Record 63 of Set 7 | birr
# Processing Record 64 of Set 7 | richards bay
# Processing Record 65 of Set 7 | kenora
# Processing Record 66 of Set 7 | asyut
# Processing Record 67 of Set 7 | seoul
# Processing Record 68 of Set 7 | mehamn
# Processing Record 69 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 70 of Set 7 | ribeira brava
# Processing Record 71 of Set 7 | kettering
# Processing Record 72 of Set 7 | saint-augustin
# Processing Record 73 of Set 7 | port lincoln
# Processing Record 74 of Set 7 | buin
# Processing Record 75 of Set 7 | boende
# Processing Record 76 of Set 7 | chishtian mandi
# Processing Record 77 of Set 7 | thinadhoo
# Processing Record 78 of Set 7 | lasa
# Processing Record 79 of Set 7 | paarl
# Processing Record 80 of Set 7 | benemerito de las americas
# Processing Record 81 of Set 7 | pathein
# Processing Record 82 of Set 7 | bonthe
# Processing Record 83 of Set 7 | alekseyevsk
# Processing Record 84 of Set 7 | severobaykalsk
# Processing Record 85 of Set 7 | manakara
# Processing Record 86 of Set 7 | nanzhou
# Processing Record 87 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 88 of Set 7 | abha
# Processing Record 89 of Set 7 | finschhafen
# Processing Record 90 of Set 7 | krasnoselkup
# Processing Record 91 of Set 7 | novobohdanivka
# Processing Record 92 of Set 7 | celestun
# Processing Record 93 of Set 7 | zavolzhsk
# Processing Record 94 of Set 7 | mishelevka
# Processing Record 95 of Set 7 | shakawe
# Processing Record 96 of Set 7 | darnah
# Processing Record 97 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 98 of Set 7 | tandalti
# Processing Record 99 of Set 7 | rio brilhante
# Processing Record 100 of Set 7 | malakal
# Processing Record 1 of Set 8 | mennecy
# Processing Record 2 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 3 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 8 | ardabil
# Processing Record 5 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 8 | loiza
# Processing Record 7 of Set 8 | beipiao
# Processing Record 8 of Set 8 | bulgan
# Processing Record 9 of Set 8 | tanga
# Processing Record 10 of Set 8 | tateyama
# Processing Record 11 of Set 8 | angra
# City not found. Skipping...
# Processing Record 12 of Set 8 | eucaliptus
# Processing Record 13 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 14 of Set 8 | grand-lahou
# Processing Record 15 of Set 8 | cavalcante
# Processing Record 16 of Set 8 | vazante
# Processing Record 17 of Set 8 | lerwick
# Processing Record 18 of Set 8 | ladan
# Processing Record 19 of Set 8 | west bay
# Processing Record 20 of Set 8 | prado
# Processing Record 21 of Set 8 | mitu
# Processing Record 22 of Set 8 | los llanos de aridane
# Processing Record 23 of Set 8 | kashi
# Processing Record 24 of Set 8 | mendota
# Processing Record 25 of Set 8 | higuey
# City not found. Skipping...
# Processing Record 26 of Set 8 | longyan
# Processing Record 27 of Set 8 | hami
# Processing Record 28 of Set 8 | kabwe
# Processing Record 29 of Set 8 | tshikapa
# Processing Record 30 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 31 of Set 8 | garowe
# Processing Record 32 of Set 8 | ponta delgada
# Processing Record 33 of Set 8 | waipawa
# Processing Record 34 of Set 8 | brebes
# Processing Record 35 of Set 8 | tamandare
# Processing Record 36 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 37 of Set 8 | yurimaguas
# Processing Record 38 of Set 8 | hambantota
# Processing Record 39 of Set 8 | upington
# Processing Record 40 of Set 8 | narrabri
# Processing Record 41 of Set 8 | port blair
# Processing Record 42 of Set 8 | talcahuano
# Processing Record 43 of Set 8 | hovd
# Processing Record 44 of Set 8 | nicoya
# Processing Record 45 of Set 8 | marathon
# Processing Record 46 of Set 8 | murdochville
# Processing Record 47 of Set 8 | izhma
# Processing Record 48 of Set 8 | gonbad-e qabus
# Processing Record 49 of Set 8 | lavrentiya
# Processing Record 50 of Set 8 | tulancingo
# Processing Record 51 of Set 8 | oytal
# Processing Record 52 of Set 8 | mudanya
# Processing Record 53 of Set 8 | seydi
# Processing Record 54 of Set 8 | zagora
# Processing Record 55 of Set 8 | sinnamary
# Processing Record 56 of Set 8 | raudeberg
# Processing Record 57 of Set 8 | tazovskiy
# Processing Record 58 of Set 8 | marrakesh
# Processing Record 59 of Set 8 | novo aripuana
# Processing Record 60 of Set 8 | ayan
# Processing Record 61 of Set 8 | maun
# Processing Record 62 of Set 8 | sungaipenuh
# Processing Record 63 of Set 8 | oktyabrskoye
# Processing Record 64 of Set 8 | beloha
# Processing Record 65 of Set 8 | caraquet
# Processing Record 66 of Set 8 | walvis bay
# Processing Record 67 of Set 8 | gorontalo
# Processing Record 68 of Set 8 | sechura
# Processing Record 69 of Set 8 | nyurba
# Processing Record 70 of Set 8 | esmeraldas
# Processing Record 71 of Set 8 | ust-ilimsk
# Processing Record 72 of Set 8 | neubiberg
# Processing Record 73 of Set 8 | shubarkuduk
# Processing Record 74 of Set 8 | sweetwater
# Processing Record 75 of Set 8 | kahului
# Processing Record 76 of Set 8 | sabang
# Processing Record 77 of Set 8 | hvide sande
# Processing Record 78 of Set 8 | owatonna
# Processing Record 79 of Set 8 | anloga
# Processing Record 80 of Set 8 | murmashi
# Processing Record 81 of Set 8 | isla mujeres
# Processing Record 82 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 83 of Set 8 | bakchar
# Processing Record 84 of Set 8 | gusau
# Processing Record 85 of Set 8 | dien bien
# City not found. Skipping...
# Processing Record 86 of Set 8 | gwanda
# Processing Record 87 of Set 8 | majene
# Processing Record 88 of Set 8 | mawlaik
# Processing Record 89 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 90 of Set 8 | maiduguri
# Processing Record 91 of Set 8 | opuwo
# Processing Record 92 of Set 8 | medvezhyegorsk
# Processing Record 93 of Set 8 | oristano
# Processing Record 94 of Set 8 | zhanakorgan
# Processing Record 95 of Set 8 | grand island
# Processing Record 96 of Set 8 | karaton
# Processing Record 97 of Set 8 | lidkoping
# Processing Record 98 of Set 8 | mbanza-ngungu
# Processing Record 99 of Set 8 | russell
# Processing Record 100 of Set 8 | durango
# Processing Record 1 of Set 9 | andros town
# Processing Record 2 of Set 9 | gayny
# Processing Record 3 of Set 9 | kharan
# Processing Record 4 of Set 9 | irbit
# Processing Record 5 of Set 9 | noumea
# Processing Record 6 of Set 9 | yerbogachen
# Processing Record 7 of Set 9 | sorland
# -----------------------------
# Cities Search Completed
# -----------------------------

# %%
len(city_data)
# Out:
# 739

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Tuatapere      NZ -46.1333  167.6833     53.01        89          66
# 1    Punta Arenas      CL -53.1500  -70.9167     48.20        87           0
# 2      The Valley      AI  18.2170  -63.0578     87.80        69          20
# 3          Adiake      CI   5.2863   -3.3040     84.20        79          20
# 4     Antofagasta      CL -23.6500  -70.4000     70.00        72          20
# ..            ...     ...      ...       ...       ...       ...         ...
# 734        Kharan      PK  28.5833   65.4167     79.61        14          88
# 735         Irbit      RU  57.6705   63.0710     26.22        48           0
# 736        Noumea      NC -22.2763  166.4572     75.99        88           0
# 737   Yerbogachen      RU  61.2767  108.0108      7.56        94          62
# 738       Sorland      NO  67.6670   12.6934     44.60        76           0
#
#      Wind Speed Current Description
# 0          3.00       broken clouds
# 1          5.75           clear sky
# 2         12.66          few clouds
# 3          6.91          few clouds
# 4         13.80          few clouds
# ..          ...                 ...
# 734        1.19     overcast clouds
# 735        4.94           clear sky
# 736        2.30           clear sky
# 737        4.00       broken clouds
# 738       16.11           clear sky
#
# [739 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = 'Weather_Database/WeatherPy_Database.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
